# %% [markdown]
# # Domain: Social Network
# Project 05: Facebook data
# Dataset contains pseudo Facebook data.
#
# Attribute Information:
# Userid : ID of user
# Age : User’s age(years)
# dob_day : Day of date of birth(1-31)
# dob_year : Year of date of birth
# dob_month : Month of date of birth
# gender : M/F
# tenure : How long have facebook users been on site
# friend_count : Total number of friends
# friendships_initiated : Friend requests sent
# likes : Total number of likes by user
# likes_received : Total number of likes received by user
# mobile_likes : Number of likes by user(through mobile)
# mobile_likes_received : Number of likes recieved by user(through mobile)
# www_likes : Number of likes by user(through desktop website)
# www_likes_received : Number of likes received by user(through desktop)
#
# Exploration ideas:
# Date of birth analysis Friend count analysis
# Tenure analysis
# Data transformations
# Frequency polygons, Boxplots.

# %%
#Import the necessary packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
# %matplotlib inline

# %%
#Read the input file in variable facebook

path = 'C:/Users/Vasu/Desktop/Vasu/LEARNING/data Analytics/UPX/Projects/Project5_Facebook/pseudo_facebook.tsv'
fb = pd.read_csv(path,sep='\t')
fb.tail()
# Out:
#         userid  age  dob_day  dob_year  dob_month  gender  tenure  \
# 98998  1268299   68        4      1945          4  female   541.0
# 98999  1256153   18       12      1995          3  female    21.0
# 99000  1195943   15       10      1998          5  female   111.0
# 99001  1468023   23       11      1990          4  female   416.0
# 99002  1397896   39       15      1974          5  female   397.0
#
#        friend_count  friendships_initiated  likes  likes_received  \
# 98998          2118                    341   3996           18089
# 98999          1968                   1720   4401           13412
# 99000          2002                   1524  11959           12554
# 99001          2560                    185   4506            6516
# 99002          2049                    768   9410           12443
#
#        mobile_likes  mobile_likes_received  www_likes  www_likes_received
# 98998          3505                  11887        491                6202
# ...

# %%
#facebook variable no of rows and columns
fb.shape
# Out:
# (99003, 15)

# %%
# setting index of te dataframe as userid

fb = fb.set_index('userid')
fb.head()
# Out:
#          age  dob_day  dob_year  dob_month  gender  tenure  friend_count  \
# userid
# 2094382   14       19      1999         11    male   266.0             0
# 1192601   14        2      1999         11  female     6.0             0
# 2083884   14       16      1999         11    male    13.0             0
# 1203168   14       25      1999         12  female    93.0             0
# 1733186   14        4      1999         12    male    82.0             0
#
#          friendships_initiated  likes  likes_received  mobile_likes  \
# userid
# 2094382                      0      0               0             0
# 1192601                      0      0               0             0
# 2083884                      0      0               0             0
# 1203168                      0      0               0             0
# 1733186                      0      0               0             0
#
#          mobile_likes_received  www_likes  www_likes_received
# userid
# ...

# %%
#Zodiac Sign - Date Range
#Aquarius (January 20 - February 18) 
#Pisces (February 19 - March 20) 
#Aries (March 21 - April 19) 
#Taurus (April 20 - May 20) 
#Gemini (May 21 - June 20) 
#Cancer (June 21 - July 22) 
#leo (July 23 - August 22) 
#Virgo (August 23 - September 22) 
#Libra (September 23 - October 22) 
#Scorpio (October 23 - November 21) 
#Sagittarius (November 22 - December 21) 
#Capricorn (December 22 - January 19) 

# Define Function
def Zodiac_Sign (row):
    if (row['dob_month']==11 and row['dob_day'] >= 22) or (row['dob_month']==12 and row['dob_day'] <= 21):
       return 'SAGITTARIUS'
    if (row['dob_month']==10 and row['dob_day'] >= 23) or (row['dob_month']==11 and row['dob_day'] <= 21):
       return 'SCORPIO'
    if (row['dob_month']==9 and row['dob_day'] >= 23) or (row['dob_month']==10 and row['dob_day'] <= 22):
       return 'LIBRA'
    if (row['dob_month']==8 and row['dob_day'] >= 23) or (row['dob_month']==9 and row['dob_day'] <= 22):
       return 'VIRGO'
    if (row['dob_month']==7 and row['dob_day'] >= 23) or (row['dob_month']==8 and row['dob_day'] <= 22):
       return 'LEO'
    if (row['dob_month']==6 and row['dob_day'] >= 21) or (row['dob_month']==7 and row['dob_day'] <= 22):
       return 'CANCER'
    if (row['dob_month']==5 and row['dob_day'] >= 21) or (row['dob_month']==6 and row['dob_day'] <= 20):
       return 'GEMINI'
    if (row['dob_month']==4 and row['dob_day'] >= 20) or (row['dob_month']==5 and row['dob_day'] <= 20):
       return 'TAURAS'
    if (row['dob_month']==3 and row['dob_day'] >= 21) or (row['dob_month']==4 and row['dob_day'] <= 19):
       return 'ARIES'
    if (row['dob_month']==2 and row['dob_day'] >= 19) or (row['dob_month']==3 and row['dob_day'] <= 20):
       return 'PISCES'
    if (row['dob_month']==1 and row['dob_day'] >= 20) or (row['dob_month']==2 and row['dob_day'] <= 18):
       return 'AQUARIUS'
    return 'CAPRICON'

# %%
fb['Zodiac_sign'] = fb.apply (lambda row: Zodiac_Sign(row),axis=1)
fb['Zodiac_sign']
fb.head()
# Out:
#          age  dob_day  dob_year  dob_month  gender  tenure  friend_count  \
# userid
# 2094382   14       19      1999         11    male   266.0             0
# 1192601   14        2      1999         11  female     6.0             0
# 2083884   14       16      1999         11    male    13.0             0
# 1203168   14       25      1999         12  female    93.0             0
# 1733186   14        4      1999         12    male    82.0             0
#
#          friendships_initiated  likes  likes_received  mobile_likes  \
# userid
# 2094382                      0      0               0             0
# 1192601                      0      0               0             0
# 2083884                      0      0               0             0
# 1203168                      0      0               0             0
# 1733186                      0      0               0             0
#
#          mobile_likes_received  www_likes  www_likes_received  Zodiac_sign
# userid
# ...

# %%
#Use describe function to see the various aspects of facebbok data

fb.describe()
# Out:
#                 age       dob_day      dob_year     dob_month        tenure  \
# count  99003.000000  99003.000000  99003.000000  99003.000000  99001.000000
# mean      37.280224     14.530408   1975.719776      6.283365    537.887375
# std       22.589748      9.015606     22.589748      3.529672    457.649874
# min       13.000000      1.000000   1900.000000      1.000000      0.000000
# 25%       20.000000      7.000000   1963.000000      3.000000    226.000000
# 50%       28.000000     14.000000   1985.000000      6.000000    412.000000
# 75%       50.000000     22.000000   1993.000000      9.000000    675.000000
# max      113.000000     31.000000   2000.000000     12.000000   3139.000000
#
#        friend_count  friendships_initiated         likes  likes_received  \
# count  99003.000000           99003.000000  99003.000000    99003.000000
# mean     196.350787             107.452471    156.078785      142.689363
# ...

# %%
#To Cater Average Likes_Received and Average Friends Count for all users

fb_all = fb[['Zodiac_sign','friend_count','likes_received']]
fb_all = fb_all.groupby('Zodiac_sign').mean().round()
fb_all.head(2)
# Out:
#              friend_count  likes_received
# Zodiac_sign
# AQUARIUS            187.0           128.0
# ARIES               201.0           130.0

# %%
#To Cater Average Likes_Received and Average Friends Count for Females

fb_females = fb[fb['gender']=='female']
fb_females = fb_females[['Zodiac_sign','friend_count','likes_received']]
fb_females = fb_females.groupby('Zodiac_sign').mean().round()
fb_females.head(2)
# Out:
#              friend_count  likes_received
# Zodiac_sign
# AQUARIUS            232.0           220.0
# ARIES               248.0           233.0

# %%
#To Cater Average Likes_Received and Average Friends Count for Males

fb_males = fb[fb['gender']=='male']
fb_males = fb_males[['Zodiac_sign','friend_count','likes_received']]
fb_males = fb_males.groupby('Zodiac_sign').mean().round()
fb_males.head(2)
# Out:
#              friend_count  likes_received
# Zodiac_sign
# AQUARIUS            158.0            65.0
# ARIES               169.0            59.0

# %%
#Restting the index for all the 2 dataframes.

fb_all = fb_all.reset_index()
fb_males = fb_males.reset_index()
fb_females = fb_females.reset_index()

# %%
fb_females.head(2)
fb_males.head(2)
# Out:
#   Zodiac_sign  friend_count  likes_received
# 0    AQUARIUS         158.0            65.0
# 1       ARIES         169.0            59.0

# %%
#Renaming the columns of the Dataframes

fb_all.columns = ['Zodiac_sign','All_friend_count','All_likes_received']
fb_males.columns = ['Zodiac_sign','Males_friend_count','Males_likes_received']
fb_females.columns = ['Zodiac_sign','Females_friend_count','Females_likes_received']
fb_females.head(2)
# Out:
#   Zodiac_sign  Females_friend_count  Females_likes_received
# 0    AQUARIUS                 232.0                   220.0
# 1       ARIES                 248.0                   233.0

# %%
#Concatinating the 3 dataframe sinto one.

fb_count = pd.concat([fb_all,fb_males,fb_females],axis=1)
fb_count
# Out:
#     Zodiac_sign  All_friend_count  All_likes_received  Zodiac_sign  \
# 0      AQUARIUS             187.0               128.0     AQUARIUS
# 1         ARIES             201.0               130.0        ARIES
# 2        CANCER             196.0               126.0       CANCER
# 3      CAPRICON             170.0               120.0     CAPRICON
# 4        GEMINI             211.0               152.0       GEMINI
# 5           LEO             209.0               202.0          LEO
# 6         LIBRA             194.0               136.0        LIBRA
# 7        PISCES             198.0               136.0       PISCES
# 8   SAGITTARIUS             198.0               144.0  SAGITTARIUS
# 9       SCORPIO             196.0               135.0      SCORPIO
# 10       TAURAS             200.0               135.0       TAURAS
# 11        VIRGO             205.0               174.0        VIRGO
#
#     Males_friend_count  Males_likes_received  Zodiac_sign  \
# ...

# %%
#Lets plot bar graph for 'Avg Friend Count' & 'Avg Likes_received' Vs Zodiac Sign

n_groups = 12
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = .85

axis_font = {'fontname':'Arial', 'size':'14'}
title_font = {'fontname':'Arial', 'size':'16', 'color':'blue'}

rects1 = plt.bar(index, fb_count['All_friend_count'], bar_width,
                 alpha=opacity,
                 color='green',
                 label='Avg. Friend Count')
 
rects2 = plt.bar(index + bar_width, fb_count['All_likes_received'], bar_width,
                 alpha=opacity,
                 color='red',
                 label='Avg.Likes_Received',)
 
plt.xlabel('Zodiac Sign',axis_font)
plt.title('Avg number of Likes_Received and Friend Count/Zodiac Sign',axis_font)
plt1 = plt.xticks(index + bar_width, ('AQUARIES','ARIES','CANCER','CAPRICON','GEMINI','LEO','LIBRA','PISCIES','SAGITTARIUS','SCORPIO','TAURAS','VIRGO'
                    ))
fig = plt.gcf()
fig.set_size_inches(15.5, 8.5)
plt.legend()

plt.tight_layout()
plt.show()

# %%
#Lets plot bar graph for 'Friend_Count Vs Zodiac Sign' for Males/Females


n_groups = 12
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = .85

axis_font = {'fontname':'Arial', 'size':'14'}
title_font = {'fontname':'Arial', 'size':'16', 'color':'blue'}

rects1 = plt.bar(index, fb_count['Males_friend_count'], bar_width,
                 alpha=opacity,
                 color='green',
                 label='Avg. Male Friend Count')
 
rects2 = plt.bar(index + bar_width, fb_count['Females_friend_count'], bar_width,
                 alpha=opacity,
                 color='red',
                 label='Avg.Female Friend Count',)
 
plt.xlabel('Zodiac Sign',axis_font)
plt.ylabel('Avg. Friend_Count',axis_font)
plt.title('Friend_Count Vs Zodiac Sign for Males/Females',axis_font)
plt1 = plt.xticks(index + bar_width, ('AQUARIES','ARIES','CANCER','CAPRICON','GEMINI','LEO','LIBRA','PISCIES','SAGITTARIUS','SCORPIO','TAURAS','VIRGO'
                                      ))
fig = plt.gcf()
fig.set_size_inches(15.5, 8.5)
plt.legend()

plt.tight_layout()
plt.show()

# %%
#Lets plot bar graph for 'Likes_Received Vs Zodiac Sign' for Males/Females

n_groups = 12
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = .85

axis_font = {'fontname':'Arial', 'size':'14'}
title_font = {'fontname':'Arial', 'size':'16', 'color':'blue'}

rects1 = plt.bar(index, fb_count['Males_likes_received'], bar_width,
                 alpha=opacity,
                 color='green',
                 label='Avg. Male Likes_Received')
 
rects2 = plt.bar(index + bar_width, fb_count['Females_likes_received'], bar_width,
                 alpha=opacity,
                 color='red',
                 label='Avg.Female Likes_Received',)
 
plt.xlabel('Zodiac Sign',axis_font)
plt.ylabel('Avg. Likes_Received',axis_font)
plt.title('Likes_Received Vs Zodiac Sign for Males/Females',axis_font)
plt1 = plt.xticks(index + bar_width, ('AQUARIES','ARIES','CANCER','CAPRICON','GEMINI','LEO','LIBRA','PISCIES','SAGITTARIUS','SCORPIO','TAURAS','VIRGO'
                                      ))
fig = plt.gcf()
fig.set_size_inches(15.5, 8.5)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Conclusion :-
# 1) More Friendly/Lovalbe People - Its done, its confirmed...LEO People followed by VIRGO are the most blessed people w.r.t Facebook parameters. Whether you count number of likes they received OR count of number of friends they have, they lead in both the categories..:).Atleast its pretty clear for Females although for males, it doesnt really matter whats your Zodiac Sign, their likes received are almost same thoughout the diff months of the year... :)
#
# 2) Not so Friendly/Reserved People - Not that good news for all who are born around January because, the above graphs shows, Capricon peoples will have less number of friends & it stands true for males as well as females.
