# %% [markdown]
# # Domain: Social Network
# Project 05: Facebook data
# Dataset contains pseudo Facebook data.
#
# Attribute Information:
# Userid : ID of user
# Age : User’s age(years)
# dob_day : Day of date of birth(1-31)
# dob_year : Year of date of birth
# dob_month : Month of date of birth
# gender : M/F
# tenure : How long have facebook users been on site
# friend_count : Total number of friends
# friendships_initiated : Friend requests sent
# likes : Total number of likes by user
# likes_received : Total number of likes received by user
# mobile_likes : Number of likes by user(through mobile)
# mobile_likes_received : Number of likes recieved by user(through mobile)
# www_likes : Number of likes by user(through desktop website)
# www_likes_received : Number of likes received by user(through desktop)
#
# Exploration ideas:
# Date of birth analysis Friend count analysis
# Tenure analysis
# Data transformations
# Frequency polygons, Boxplots.

# %%
#Import the necessary packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
# %matplotlib inline

# %%
#Read the input file in variable facebook

path = 'C:/Users/Vasu/Desktop/Vasu/LEARNING/data Analytics/UPX/Projects/Project5_Facebook/pseudo_facebook.tsv'
fb = pd.read_csv(path,sep='\t')
fb.tail()
# Out:
#         userid  age  dob_day  dob_year  dob_month  gender  tenure  \
# 98998  1268299   68        4      1945          4  female   541.0
# 98999  1256153   18       12      1995          3  female    21.0
# 99000  1195943   15       10      1998          5  female   111.0
# 99001  1468023   23       11      1990          4  female   416.0
# 99002  1397896   39       15      1974          5  female   397.0
#
#        friend_count  friendships_initiated  likes  likes_received  \
# 98998          2118                    341   3996           18089
# 98999          1968                   1720   4401           13412
# 99000          2002                   1524  11959           12554
# 99001          2560                    185   4506            6516
# 99002          2049                    768   9410           12443
#
#        mobile_likes  mobile_likes_received  www_likes  www_likes_received
# 98998          3505                  11887        491                6202
# ...

# %%
#facebook variable no of rows and columns
fb.shape
# Out:
# (99003, 15)

# %%
# setting index of te dataframe as userid

fb = fb.set_index('userid')
fb.head()
# Out:
#          age  dob_day  dob_year  dob_month  gender  tenure  friend_count  \
# userid
# 2094382   14       19      1999         11    male   266.0             0
# 1192601   14        2      1999         11  female     6.0             0
# 2083884   14       16      1999         11    male    13.0             0
# 1203168   14       25      1999         12  female    93.0             0
# 1733186   14        4      1999         12    male    82.0             0
#
#          friendships_initiated  likes  likes_received  mobile_likes  \
# userid
# 2094382                      0      0               0             0
# 1192601                      0      0               0             0
# 2083884                      0      0               0             0
# 1203168                      0      0               0             0
# 1733186                      0      0               0             0
#
#          mobile_likes_received  www_likes  www_likes_received
# userid
# ...

# %%
#Use describe function to see the various aspects of facebbok data

fb.describe()
# Out:
#                 age       dob_day      dob_year     dob_month        tenure  \
# count  99003.000000  99003.000000  99003.000000  99003.000000  99001.000000
# mean      37.280224     14.530408   1975.719776      6.283365    537.887375
# std       22.589748      9.015606     22.589748      3.529672    457.649874
# min       13.000000      1.000000   1900.000000      1.000000      0.000000
# 25%       20.000000      7.000000   1963.000000      3.000000    226.000000
# 50%       28.000000     14.000000   1985.000000      6.000000    412.000000
# 75%       50.000000     22.000000   1993.000000      9.000000    675.000000
# max      113.000000     31.000000   2000.000000     12.000000   3139.000000
#
#        friend_count  friendships_initiated         likes  likes_received  \
# count  99003.000000           99003.000000  99003.000000    99003.000000
# mean     196.350787             107.452471    156.078785      142.689363
# ...

# %%
#Lets try for Q06
fb_males = fb[fb['gender']=='male']
fb_males = fb_males[['dob_month','friend_count']]
fb_females = fb[fb['gender']=='female']
fb_females = fb_females[['dob_month','friend_count']]
fb_females = fb_females.groupby('dob_month').mean()
fb_females
fb_males = fb_males.groupby('dob_month').mean()
fb_males
# Out:
#            friend_count
# dob_month
# 1            137.493617
# 2            154.728430
# 3            163.441575
# 4            171.034785
# 5            174.536274
# 6            173.879883
# 7            162.590043
# 8            179.051192
# 9            174.465416
# 10           163.356594
# 11           169.162293
# 12           175.450449

# %%
fb_males.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 1 to 12
# Data columns (total 1 columns):
# friend_count    12 non-null float64
# dtypes: float64(1)
# memory usage: 192.0 bytes

# %%
fb_counts_month = [fb_males,fb_females]
result = pd.concat(fb_counts_month,axis=1)
result
result=result.reset_index()

# %%
result.dtypes
# Out:
# dob_month         int64
# friend_count    float64
# friend_count    float64
# dtype: object

# %%
result.columns = ['month','males','females']
result
# Out:
#     month       males     females
# 0       1  137.493617  218.042179
# 1       2  154.728430  235.196277
# 2       3  163.441575  252.692471
# 3       4  171.034785  244.522184
# 4       5  174.536274  249.068369
# 5       6  173.879883  248.448973
# 6       7  162.590043  242.380685
# 7       8  179.051192  258.024781
# 8       9  174.465416  238.530723
# 9      10  163.356594  238.467348
# 10     11  169.162293  242.864610
# 11     12  175.450449  239.770456

# %%
#Lets plot bar graph for 'Month of Birth' Vs Friend Count

n_groups = 12
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = .85
 
rects1 = plt.bar(index, result['males'], bar_width,
                 alpha=opacity,
                 color='blue',
                 label='Males')
 
rects2 = plt.bar(index + bar_width, result['females'], bar_width,
                 alpha=opacity,
                 color='pink',
                 label='Females')
 
plt.xlabel('Month')
plt.ylabel('Friends Count')
plt.title('Month of Birth Vs Friend Count')
plt.xticks(index + bar_width, ('Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'))
plt.legend()
 
plt.tight_layout()
plt.show()

# %%
#Lets also try the same plot in Line graph as well to compare if the above plot looks much better.

plt.plot(result['month'],result['males'],'blue',linewidth=4.0)
plt.plot(result['month'],result['females'],'green',linewidth=4.0)
plt.xlabel('Month of Birth',fontsize = 'x-large')
plt.ylabel('Avg no of Friends',fontsize = 'x-large')
plt.legend(['males','females'],loc='lower right',fontsize = 'x-large')
plt.show()

# %% [markdown]
# Conclusion :-
# 1) More Friendly People - So, it seems irrespective of gender, people who are born in August are more friendly in nature, atleast they ave more friends, thats what the above plots confirms us.
# 2) Not so Friendly/Reserved People - Not that good news for all who are born in January, the above graphs shows, those who are born in January will have less number of friends & it stands true for males as well as females.
